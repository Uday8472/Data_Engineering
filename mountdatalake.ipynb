# %%
storage_account_name = 'databrixdemo'
client_id = '41a5d094-e076-4f2c-92ae-0f69c04c4003'
tenant_id = 'eeb98c07-85d0-467a-8312-86e2e8349c1e'
client_secret = 'FYk8Q~NMwD.V4zGzPONlZ13S0Jy3HOONoW3UjaL6'

# %%
# configs = {"fs.azure.account.auth.type": "OAuth",
#            "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
#            "fs.azure.account.oauth2.client.id": client_id,
#            "fs.azure.account.oauth2.client.secret": client_secret,
#            "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/<directory-id>/oauth2/token"}

configs = {"fs.azure.account.auth.type": "OAuth",
           "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
           "fs.azure.account.oauth2.client.id": f"{client_id}",
           "fs.azure.account.oauth2.client.secret": f"{client_secret}",
           "fs.azure.account.oauth2.client.endpoint": f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"}

# %%
# def mount_adls(containername):
#     dbutils.fs.mount(
#   source = "abfss://<container-name>@<storage-account-name>.dfs.core.windows.net/",
#   mount_point = "/mnt/<mount-name>",
#   extra_configs = configs)
    
def mount_adls(container_name):
    dbutils.fs.mount(
    source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/",
    mount_point = f"/mnt/{storage_account_name}/{container_name}",
    extra_configs = configs)

# %%
mount_adls('original')
print('Succesfully mounted')
# Out:
# Succesfully mounted

# %%
dbutils.fs.ls (f"/mnt/{storage_account_name}/original")
# Out:
# Out[23]: [FileInfo(path='dbfs:/mnt/databrixdemo/original/IPL Matches 2008-2020.csv', name='IPL Matches 2008-2020.csv', size=150820, modificationTime=1674466608000)]

# %%
df = spark.read.csv('dbfs:/mnt/databrixdemo/original/IPL Matches 2008-2020.csv',header=True, inferSchema=True)
display(df)

# %%
df_processed = df.select('id','city','date','player_of_match')
display(df_processed)

# %%
mount_adls('copied')
print('Successfully mounted new container')
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# <command-2328032415828997> in <cell line: 1>()
# ----> 1 mount_adls('copied')
#       2 print('Successfully mounted new container')
#       3 df_processed.write.mode("overwrite").csv(f"/mnt/{storage_account_name}/copied/ipl.csv",header=True,coalesce=1)
#       4 print("successfully written to new container")
#
# <command-2328032415828992> in mount_adls(container_name)
#       6
#       7 def mount_adls(container_name):
# ----> 8     dbutils.fs.mount(
#       9     source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net/",
#      10     mount_point = f"/mnt/{storage_account_name}/{container_name}",
#
# /databricks/python_shell/dbruntime/dbutils.py in f_with_exception_handling(*args, **kwargs)
#     360                     exc.__context__ = None
#     361                     exc.__cause__ = None
# ...

# %%
df_processed.write.mode("overwrite").csv(f"/mnt/{storage_account_name}/copied/ipl.csv",header=True)
print("successfully written to new container")
# Out:
# successfully written to new container
